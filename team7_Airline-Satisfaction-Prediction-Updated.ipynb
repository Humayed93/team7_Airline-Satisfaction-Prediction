# %% [markdown]
# # Install necessary packages
# This block installs the s3fs package using the %pip magic command.

# %%
# %pip install s3fs
# Out:
# Requirement already satisfied: s3fs in /opt/conda/lib/python3.10/site-packages (2024.3.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.10/site-packages (from s3fs) (2.12.1)
# Collecting fsspec==2024.3.1 (from s3fs)
#   Using cached fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from s3fs) (3.9.3)
# Requirement already satisfied: botocore<1.34.52,>=1.34.41 in /opt/conda/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.51)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.26.18)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.52,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Using cached fsspec-2024.3.1-py3-none-any.whl (171 kB)
# WARNING: Error parsing requirements for fsspec: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/fsspec-2023.6.0.dist-info/METADATA'
# Installing collected packages: fsspec
#   Attempting uninstall: fsspec
#     WARNING: No metadata found in /opt/conda/lib/python3.10/site-packages
#     Found existing installation: fsspec 2023.6.0
# ERROR: Cannot uninstall fsspec 2023.6.0, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps fsspec==2023.6.0'.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import libraries
# Here, necessary libraries and modules are imported, including boto3 for AWS interactions, sagemaker for using SageMaker functionalities,
#  pandas for data manipulation, and various functions from sklearn for machine learning metrics.

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.estimator import Estimator
from sagemaker.inputs import TrainingInput

import numpy as np
import io
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sagemaker.serializers import CSVSerializer
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# # Load data from S3
# This section loads training and testing datasets from Amazon S3 into pandas DataFrames.

# %%
train_data = pd.read_csv(
    's3://team7-bucket/Airline_Dataset/train.csv'
)

# %%
test_val_data = pd.read_csv(
    's3://team7-bucket/Airline_Dataset/test.csv'
)

# %%
train_data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %% [markdown]
# # Define transformation functions
# Here, transformation functions are defined to preprocess categorical variables into numerical format.

# %%
def transform_gender(x):
    if x == 'Female':
        return 1
    elif x == 'Male':
        return 0
    else:
        return -1
    
def transform_customer_type(x):
    if x == 'Loyal Customer':
        return 1
    elif x == 'disloyal Customer':
        return 0
    else:
        return -1
    
def transform_travel_type(x):
    if x == 'Business travel':
        return 1
    elif x == 'Personal Travel':
        return 0
    else:
        return -1
    
def transform_class(x):
    if x == 'Business':
        return 2
    elif x == 'Eco Plus':
        return 1
    elif x == 'Eco':
        return 0    
    else:
        return -1
    
def transform_satisfaction(x):
    if x == 'satisfied':
        return 1
    elif x == 'neutral or dissatisfied':
        return 0
    else:
        return -1
    
def process_data(df):
    df = df.drop(['Unnamed: 0', 'id'], axis = 1)
    df['Gender'] = df['Gender'].apply(transform_gender)
    df['Customer Type'] = df['Customer Type'].apply(transform_customer_type)
    df['Type of Travel'] = df['Type of Travel'].apply(transform_travel_type)
    df['Class'] = df['Class'].apply(transform_class)
    df['satisfaction'] = df['satisfaction'].apply(transform_satisfaction)
    df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median(), inplace = True)
    
    return df

# %% [markdown]
# # Apply transformations to data
# The defined transformation functions are applied to preprocess the loaded datasets.

# %%
train = process_data(train_data)
test_val = process_data(test_val_data)

# %%
train.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              1   13               0      1              460
# 1       0              0   25               1      2              235
# 2       1              1   26               1      2             1142
# 3       1              1   25               1      2              562
# 4       0              1   61               1      2              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %% [markdown]
# # Split data into train, validation, and test sets
# The data is split into training, validation, and test sets using train_test_split.

# %%
val, test = train_test_split(test_val, train_size=0.5, random_state=1200)

# %%
train.shape, val.shape, test.shape
# Out:
# ((103904, 23), (12988, 23), (12988, 23))

# %% [markdown]
# # Prepare train, validation, and test sets
# This block prepares the training, validation, and test sets for modeling and aligns their columns.

# %%
# Assuming 'train' and 'val' DataFrames contain your training and validation data
X_train = train.drop('satisfaction', axis=1)  # Features for training
y_train = train['satisfaction']  # Target variable for training

X_val = val.drop('satisfaction', axis=1)  # Features for validation
y_val = val['satisfaction']  # Target variable for validation

X_test = test.drop('satisfaction', axis=1)  # Features for testing
y_test = test['satisfaction']  # Target variable for testing

# %%
train = pd.concat([y_train, X_train], axis=1)
val = pd.concat([y_val, X_val], axis=1)

# %%
# After one-hot encoding or any other preprocessing
train, val = train.align(val, join='inner', axis=1)  # Ensures both DataFrames have the same columns in the same order

# %%
train.head()
# Out:
#    satisfaction  Gender  Customer Type  Age  Type of Travel  Class  \
# 0             0       0              1   13               0      1
# 1             0       0              0   25               1      2
# 2             1       1              1   26               1      2
# 3             0       1              1   25               1      2
# 4             1       0              1   61               1      2
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Seat comfort  Inflight entertainment  \
# 0                       3  ...             5                       5
# 1                       3  ...             1                       1
# 2                       2  ...             5                       5
# 3                       5  ...             2                       2
# 4                       3  ...             5                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Upload train and validation data to S3
# Train and validation datasets are uploaded to S3 for training the model.

# %%
s3 = boto3.resource('s3')

# %%
def upload_to_s3(df, bucket, filename):
    
    placeholder = io.StringIO()
    df.to_csv(placeholder, header=False, index=False)
    object = s3.Object(bucket, filename)
    object.put(Body=placeholder.getvalue())

# %%
bucket = 'team7-bucket'

# %%
upload_to_s3(train, bucket, 'sagemaker-data/train.csv')

# %%
upload_to_s3(val, bucket, 'sagemaker-data/val.csv')

# %%
# Define the data location
train_data_location = f's3://{bucket}/sagemaker-data/train.csv'
val_data_location = f's3://{bucket}/sagemaker-data/val.csv'

# Specify output location for model artifacts
output_location = f's3://{bucket}/sagemaker-models/'

# %% [markdown]
# # Define training input
# Training inputs are defined using TrainingInput for training and validation datasets.

# %%
# Specify the input data configuration using TrainingInput
train_input = TrainingInput(s3_data=train_data_location, content_type='csv')
val_input = TrainingInput(s3_data=val_data_location, content_type='csv')

# %% [markdown]
# # Set up SageMaker environment
# The SageMaker environment is set up, including getting the execution role and retrieving the XGBoost image URI.

# %%
# Get the current execution role and XGBoost image URI (ensure the region is correct)
role = get_execution_role()
xgboost_image = sagemaker.image_uris.retrieve(framework='xgboost', region=boto3.Session().region_name, version='1.0-1')

# %% [markdown]
# # Define XGBoost model
# An XGBoost model is defined using the Estimator class, specifying parameters like instance type, instance count, etc.

# %%
# Define the model
xgboost_model = Estimator(image_uri=xgboost_image,
                          role=role,
                          instance_count=1,
                          instance_type='ml.m4.xlarge',
                          output_path=output_location,
                          sagemaker_session=sagemaker.Session())

# %% [markdown]
# # Set hyperparameters and launch training job
# Hyperparameters for the XGBoost model are set, and the training job is launched with fit().

# %%
# Set the hyperparameters
xgboost_model.set_hyperparameters(objective='binary:logistic',
                                  num_round=1000)

# %%
# Launch the training job
xgboost_model.fit({'train': train_input, 'validation': val_input})
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2024-04-01-20-21-28-858
# 2024-04-01 20:21:29 Starting - Starting the training job...
# 2024-04-01 20:21:44 Starting - Preparing the instances for training...
# 2024-04-01 20:22:24 Downloading - Downloading input data...
# 2024-04-01 20:22:59 Downloading - Downloading the training image......
# 2024-04-01 20:23:44 Training - Training image download completed. Training in progress...[2024-04-01 20:24:00.047 ip-10-0-203-165.ec2.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# [20:24:00] 103904x22 matrix with 2285888 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [20:24:00] 12988x22 matrix with 285736 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [2024-04-01 20:24:00.310 ip-10-0-203-165.ec2.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-04-01 20:24:00.311 ip-10-0-203-165.ec2.internal:7 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-04-01 20:24:00.311 ip-10-0-203-165.ec2.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2024-04-01 20:24:00.312 ip-10-0-203-165.ec2.internal:7 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2024-04-01 20:24:00.312 ip-10-0-203-165.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 103904 rows
# INFO:root:Validation matrix has 12988 rows
# [20:24:00] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [0]#011train-error:0.07998#011validation-error:0.07684
# [2024-04-01 20:24:00.498 ip-10-0-203-165.ec2.internal:7 INFO hook.py:423] Monitoring the collections: metrics
# [2024-04-01 20:24:00.501 ip-10-0-203-165.ec2.internal:7 INFO hook.py:486] Hook is writing from the hook with pid: 7
# [1]#011train-error:0.07226#011validation-error:0.06922
# [2]#011train-error:0.06942#011validation-error:0.06637
# [3]#011train-error:0.06666#011validation-error:0.06360
# [4]#011train-error:0.05923#011validation-error:0.05567
# [5]#011train-error:0.05765#011validation-error:0.05605
# [6]#011train-error:0.05528#011validation-error:0.05259
# [7]#011train-error:0.05288#011validation-error:0.04966
# [8]#011train-error:0.05137#011validation-error:0.04935
# [9]#011train-error:0.05052#011validation-error:0.04750
# [10]#011train-error:0.04966#011validation-error:0.04712
# [11]#011train-error:0.04861#011validation-error:0.04681
# [12]#011train-error:0.04808#011validation-error:0.04620
# [13]#011train-error:0.04647#011validation-error:0.04573
# [14]#011train-error:0.04586#011validation-error:0.04404
# [15]#011train-error:0.04528#011validation-error:0.04389
# [16]#011train-error:0.04513#011validation-error:0.04373
# [17]#011train-error:0.04327#011validation-error:0.04350
# [18]#011train-error:0.04310#011validation-error:0.04281
# [19]#011train-error:0.04185#011validation-error:0.04173
# [20]#011train-error:0.04132#011validation-error:0.04119
# [21]#011train-error:0.04113#011validation-error:0.04127
# [22]#011train-error:0.04048#011validation-error:0.04104
# [23]#011train-error:0.04016#011validation-error:0.04042
# [24]#011train-error:0.03963#011validation-error:0.03988
# [25]#011train-error:0.03883#011validation-error:0.03965
# [26]#011train-error:0.03826#011validation-error:0.03888
# [27]#011train-error:0.03744#011validation-error:0.03865
# [28]#011train-error:0.03734#011validation-error:0.03834
# [29]#011train-error:0.03716#011validation-error:0.03811
# [30]#011train-error:0.03659#011validation-error:0.03780
# [31]#011train-error:0.03640#011validation-error:0.03773
# [32]#011train-error:0.03547#011validation-error:0.03765
# [33]#011train-error:0.03527#011validation-error:0.03773
# [34]#011train-error:0.03487#011validation-error:0.03673
# [35]#011train-error:0.03475#011validation-error:0.03688
# [36]#011train-error:0.03470#011validation-error:0.03719
# [37]#011train-error:0.03411#011validation-error:0.03696
# [38]#011train-error:0.03408#011validation-error:0.03680
# [39]#011train-error:0.03356#011validation-error:0.03696
# [40]#011train-error:0.03337#011validation-error:0.03673
# [41]#011train-error:0.03335#011validation-error:0.03673
# [42]#011train-error:0.03316#011validation-error:0.03680
# [43]#011train-error:0.03280#011validation-error:0.03673
# [44]#011train-error:0.03250#011validation-error:0.03680
# [45]#011train-error:0.03241#011validation-error:0.03680
# [46]#011train-error:0.03204#011validation-error:0.03596
# [47]#011train-error:0.03170#011validation-error:0.03603
# [48]#011train-error:0.03164#011validation-error:0.03596
# [49]#011train-error:0.03144#011validation-error:0.03634
# [50]#011train-error:0.03150#011validation-error:0.03603
# [51]#011train-error:0.03134#011validation-error:0.03611
# [52]#011train-error:0.03117#011validation-error:0.03588
# [53]#011train-error:0.03103#011validation-error:0.03572
# [54]#011train-error:0.03104#011validation-error:0.03596
# [55]#011train-error:0.03106#011validation-error:0.03596
# [56]#011train-error:0.03093#011validation-error:0.03565
# [57]#011train-error:0.03085#011validation-error:0.03557
# [58]#011train-error:0.03068#011validation-error:0.03542
# [59]#011train-error:0.03061#011validation-error:0.03557
# [60]#011train-error:0.03052#011validation-error:0.03572
# [61]#011train-error:0.03034#011validation-error:0.03596
# [62]#011train-error:0.03020#011validation-error:0.03588
# [63]#011train-error:0.02995#011validation-error:0.03557
# [64]#011train-error:0.02976#011validation-error:0.03588
# [65]#011train-error:0.02964#011validation-error:0.03588
# [66]#011train-error:0.02956#011validation-error:0.03588
# [67]#011train-error:0.02897#011validation-error:0.03626
# [68]#011train-error:0.02884#011validation-error:0.03649
# [69]#011train-error:0.02880#011validation-error:0.03611
# [70]#011train-error:0.02871#011validation-error:0.03596
# [71]#011train-error:0.02857#011validation-error:0.03572
# [72]#011train-error:0.02848#011validation-error:0.03542
# [73]#011train-error:0.02832#011validation-error:0.03596
# [74]#011train-error:0.02824#011validation-error:0.03603
# [75]#011train-error:0.02821#011validation-error:0.03603
# [76]#011train-error:0.02812#011validation-error:0.03588
# [77]#011train-error:0.02811#011validation-error:0.03588
# [78]#011train-error:0.02809#011validation-error:0.03596
# [79]#011train-error:0.02772#011validation-error:0.03588
# [80]#011train-error:0.02759#011validation-error:0.03580
# [81]#011train-error:0.02745#011validation-error:0.03588
# [82]#011train-error:0.02731#011validation-error:0.03565
# [83]#011train-error:0.02723#011validation-error:0.03549
# [84]#011train-error:0.02705#011validation-error:0.03534
# [85]#011train-error:0.02675#011validation-error:0.03526
# [86]#011train-error:0.02668#011validation-error:0.03526
# [87]#011train-error:0.02649#011validation-error:0.03542
# [88]#011train-error:0.02633#011validation-error:0.03511
# [89]#011train-error:0.02627#011validation-error:0.03503
# [90]#011train-error:0.02628#011validation-error:0.03526
# [91]#011train-error:0.02617#011validation-error:0.03534
# [92]#011train-error:0.02606#011validation-error:0.03519
# [93]#011train-error:0.02593#011validation-error:0.03534
# [94]#011train-error:0.02589#011validation-error:0.03534
# [95]#011train-error:0.02568#011validation-error:0.03549
# [96]#011train-error:0.02567#011validation-error:0.03549
# [97]#011train-error:0.02564#011validation-error:0.03557
# [98]#011train-error:0.02542#011validation-error:0.03534
# [99]#011train-error:0.02524#011validation-error:0.03519
# [100]#011train-error:0.02517#011validation-error:0.03526
# [101]#011train-error:0.02509#011validation-error:0.03526
# [102]#011train-error:0.02489#011validation-error:0.03542
# [103]#011train-error:0.02484#011validation-error:0.03526
# [104]#011train-error:0.02477#011validation-error:0.03534
# [105]#011train-error:0.02461#011validation-error:0.03526
# [106]#011train-error:0.02443#011validation-error:0.03572
# [107]#011train-error:0.02426#011validation-error:0.03519
# [108]#011train-error:0.02409#011validation-error:0.03549
# [109]#011train-error:0.02408#011validation-error:0.03542
# [110]#011train-error:0.02407#011validation-error:0.03542
# [111]#011train-error:0.02403#011validation-error:0.03557
# [112]#011train-error:0.02396#011validation-error:0.03557
# [113]#011train-error:0.02384#011validation-error:0.03526
# [114]#011train-error:0.02365#011validation-error:0.03526
# [115]#011train-error:0.02360#011validation-error:0.03542
# [116]#011train-error:0.02344#011validation-error:0.03511
# [117]#011train-error:0.02324#011validation-error:0.03526
# [118]#011train-error:0.02310#011validation-error:0.03534
# [119]#011train-error:0.02296#011validation-error:0.03526
# [120]#011train-error:0.02296#011validation-error:0.03519
# [121]#011train-error:0.02290#011validation-error:0.03519
# [122]#011train-error:0.02277#011validation-error:0.03519
# [123]#011train-error:0.02276#011validation-error:0.03519
# [124]#011train-error:0.02275#011validation-error:0.03519
# [125]#011train-error:0.02255#011validation-error:0.03519
# [126]#011train-error:0.02243#011validation-error:0.03519
# [127]#011train-error:0.02245#011validation-error:0.03526
# [128]#011train-error:0.02222#011validation-error:0.03534
# [129]#011train-error:0.02195#011validation-error:0.03534
# [130]#011train-error:0.02190#011validation-error:0.03557
# [131]#011train-error:0.02167#011validation-error:0.03549
# [132]#011train-error:0.02162#011validation-error:0.03534
# [133]#011train-error:0.02159#011validation-error:0.03549
# [134]#011train-error:0.02151#011validation-error:0.03565
# [135]#011train-error:0.02143#011validation-error:0.03557
# [136]#011train-error:0.02126#011validation-error:0.03572
# [137]#011train-error:0.02116#011validation-error:0.03557
# [138]#011train-error:0.02086#011validation-error:0.03572
# [139]#011train-error:0.02064#011validation-error:0.03572
# [140]#011train-error:0.02039#011validation-error:0.03557
# [141]#011train-error:0.02023#011validation-error:0.03565
# [142]#011train-error:0.02015#011validation-error:0.03557
# [143]#011train-error:0.02016#011validation-error:0.03557
# [144]#011train-error:0.02014#011validation-error:0.03557
# [145]#011train-error:0.02005#011validation-error:0.03549
# [146]#011train-error:0.01982#011validation-error:0.03596
# [147]#011train-error:0.01980#011validation-error:0.03557
# [148]#011train-error:0.01958#011validation-error:0.03549
# [149]#011train-error:0.01953#011validation-error:0.03542
# [150]#011train-error:0.01951#011validation-error:0.03549
# [151]#011train-error:0.01943#011validation-error:0.03534
# [152]#011train-error:0.01941#011validation-error:0.03542
# [153]#011train-error:0.01933#011validation-error:0.03534
# [154]#011train-error:0.01915#011validation-error:0.03495
# [155]#011train-error:0.01912#011validation-error:0.03488
# [156]#011train-error:0.01914#011validation-error:0.03465
# [157]#011train-error:0.01902#011validation-error:0.03472
# [158]#011train-error:0.01898#011validation-error:0.03472
# [159]#011train-error:0.01897#011validation-error:0.03472
# [160]#011train-error:0.01874#011validation-error:0.03472
# [161]#011train-error:0.01846#011validation-error:0.03503
# [162]#011train-error:0.01833#011validation-error:0.03503
# [163]#011train-error:0.01813#011validation-error:0.03503
# [164]#011train-error:0.01810#011validation-error:0.03503
# [165]#011train-error:0.01789#011validation-error:0.03495
# [166]#011train-error:0.01778#011validation-error:0.03519
# [167]#011train-error:0.01767#011validation-error:0.03549
# [168]#011train-error:0.01759#011validation-error:0.03565
# [169]#011train-error:0.01751#011validation-error:0.03565
# [170]#011train-error:0.01725#011validation-error:0.03526
# [171]#011train-error:0.01711#011validation-error:0.03526
# [172]#011train-error:0.01710#011validation-error:0.03519
# [173]#011train-error:0.01696#011validation-error:0.03503
# [174]#011train-error:0.01694#011validation-error:0.03511
# [175]#011train-error:0.01693#011validation-error:0.03511
# [176]#011train-error:0.01663#011validation-error:0.03495
# [177]#011train-error:0.01655#011validation-error:0.03488
# [178]#011train-error:0.01647#011validation-error:0.03465
# [179]#011train-error:0.01640#011validation-error:0.03465
# [180]#011train-error:0.01633#011validation-error:0.03465
# [181]#011train-error:0.01632#011validation-error:0.03480
# [182]#011train-error:0.01622#011validation-error:0.03495
# [183]#011train-error:0.01609#011validation-error:0.03495
# [184]#011train-error:0.01602#011validation-error:0.03511
# [185]#011train-error:0.01584#011validation-error:0.03526
# [186]#011train-error:0.01559#011validation-error:0.03511
# [187]#011train-error:0.01544#011validation-error:0.03534
# [188]#011train-error:0.01532#011validation-error:0.03519
# [189]#011train-error:0.01524#011validation-error:0.03534
# [190]#011train-error:0.01524#011validation-error:0.03534
# [191]#011train-error:0.01505#011validation-error:0.03549
# [192]#011train-error:0.01504#011validation-error:0.03580
# [193]#011train-error:0.01498#011validation-error:0.03588
# [194]#011train-error:0.01485#011validation-error:0.03534
# [195]#011train-error:0.01484#011validation-error:0.03534
# [196]#011train-error:0.01474#011validation-error:0.03549
# [197]#011train-error:0.01461#011validation-error:0.03542
# [198]#011train-error:0.01450#011validation-error:0.03557
# [199]#011train-error:0.01431#011validation-error:0.03588
# [200]#011train-error:0.01431#011validation-error:0.03588
# [201]#011train-error:0.01415#011validation-error:0.03596
# [202]#011train-error:0.01407#011validation-error:0.03580
# [203]#011train-error:0.01401#011validation-error:0.03565
# [204]#011train-error:0.01384#011validation-error:0.03603
# [205]#011train-error:0.01368#011validation-error:0.03603
# [206]#011train-error:0.01352#011validation-error:0.03603
# [207]#011train-error:0.01348#011validation-error:0.03619
# [208]#011train-error:0.01347#011validation-error:0.03626
# [209]#011train-error:0.01344#011validation-error:0.03626
# [210]#011train-error:0.01342#011validation-error:0.03626
# [211]#011train-error:0.01337#011validation-error:0.03626
# [212]#011train-error:0.01331#011validation-error:0.03626
# [213]#011train-error:0.01327#011validation-error:0.03619
# [214]#011train-error:0.01317#011validation-error:0.03642
# [215]#011train-error:0.01316#011validation-error:0.03642
# [216]#011train-error:0.01302#011validation-error:0.03634
# [217]#011train-error:0.01297#011validation-error:0.03611
# [218]#011train-error:0.01280#011validation-error:0.03642
# [219]#011train-error:0.01275#011validation-error:0.03665
# [220]#011train-error:0.01272#011validation-error:0.03665
# [221]#011train-error:0.01273#011validation-error:0.03665
# [222]#011train-error:0.01273#011validation-error:0.03665
# [223]#011train-error:0.01273#011validation-error:0.03649
# [224]#011train-error:0.01269#011validation-error:0.03642
# [225]#011train-error:0.01259#011validation-error:0.03673
# [226]#011train-error:0.01264#011validation-error:0.03596
# [227]#011train-error:0.01259#011validation-error:0.03603
# [228]#011train-error:0.01255#011validation-error:0.03588
# [229]#011train-error:0.01253#011validation-error:0.03596
# [230]#011train-error:0.01237#011validation-error:0.03642
# [231]#011train-error:0.01233#011validation-error:0.03634
# [232]#011train-error:0.01218#011validation-error:0.03642
# [233]#011train-error:0.01217#011validation-error:0.03642
# [234]#011train-error:0.01203#011validation-error:0.03634
# [235]#011train-error:0.01203#011validation-error:0.03634
# [236]#011train-error:0.01192#011validation-error:0.03642
# [237]#011train-error:0.01191#011validation-error:0.03634
# [238]#011train-error:0.01192#011validation-error:0.03626
# [239]#011train-error:0.01195#011validation-error:0.03626
# [240]#011train-error:0.01192#011validation-error:0.03626
# [241]#011train-error:0.01175#011validation-error:0.03634
# [242]#011train-error:0.01162#011validation-error:0.03596
# [243]#011train-error:0.01163#011validation-error:0.03603
# [244]#011train-error:0.01151#011validation-error:0.03603
# [245]#011train-error:0.01148#011validation-error:0.03603
# [246]#011train-error:0.01147#011validation-error:0.03611
# [247]#011train-error:0.01148#011validation-error:0.03611
# [248]#011train-error:0.01139#011validation-error:0.03619
# [249]#011train-error:0.01119#011validation-error:0.03611
# [250]#011train-error:0.01092#011validation-error:0.03611
# [251]#011train-error:0.01094#011validation-error:0.03611
# [252]#011train-error:0.01087#011validation-error:0.03626
# [253]#011train-error:0.01079#011validation-error:0.03580
# [254]#011train-error:0.01082#011validation-error:0.03557
# [255]#011train-error:0.01079#011validation-error:0.03580
# [256]#011train-error:0.01072#011validation-error:0.03588
# [257]#011train-error:0.01070#011validation-error:0.03580
# [258]#011train-error:0.01047#011validation-error:0.03580
# [259]#011train-error:0.01038#011validation-error:0.03572
# [260]#011train-error:0.01034#011validation-error:0.03572
# [261]#011train-error:0.01028#011validation-error:0.03580
# [262]#011train-error:0.01022#011validation-error:0.03588
# [263]#011train-error:0.01017#011validation-error:0.03596
# [264]#011train-error:0.01004#011validation-error:0.03588
# [265]#011train-error:0.00997#011validation-error:0.03580
# [266]#011train-error:0.00995#011validation-error:0.03588
# [267]#011train-error:0.00996#011validation-error:0.03580
# [268]#011train-error:0.00985#011validation-error:0.03588
# [269]#011train-error:0.00969#011validation-error:0.03596
# [270]#011train-error:0.00948#011validation-error:0.03596
# [271]#011train-error:0.00942#011validation-error:0.03596
# [272]#011train-error:0.00948#011validation-error:0.03603
# [273]#011train-error:0.00948#011validation-error:0.03588
# [274]#011train-error:0.00929#011validation-error:0.03588
# [275]#011train-error:0.00918#011validation-error:0.03588
# [276]#011train-error:0.00915#011validation-error:0.03603
# [277]#011train-error:0.00900#011validation-error:0.03603
# [278]#011train-error:0.00889#011validation-error:0.03626
# [279]#011train-error:0.00877#011validation-error:0.03596
# [280]#011train-error:0.00875#011validation-error:0.03588
# [281]#011train-error:0.00864#011validation-error:0.03580
# [282]#011train-error:0.00863#011validation-error:0.03580
# [283]#011train-error:0.00862#011validation-error:0.03580
# [284]#011train-error:0.00857#011validation-error:0.03596
# [285]#011train-error:0.00863#011validation-error:0.03588
# [286]#011train-error:0.00849#011validation-error:0.03580
# [287]#011train-error:0.00838#011validation-error:0.03580
# [288]#011train-error:0.00825#011validation-error:0.03572
# [289]#011train-error:0.00834#011validation-error:0.03580
# [290]#011train-error:0.00830#011validation-error:0.03572
# [291]#011train-error:0.00820#011validation-error:0.03565
# [292]#011train-error:0.00809#011validation-error:0.03596
# [293]#011train-error:0.00809#011validation-error:0.03603
# [294]#011train-error:0.00798#011validation-error:0.03588
# [295]#011train-error:0.00793#011validation-error:0.03611
# [296]#011train-error:0.00787#011validation-error:0.03603
# [297]#011train-error:0.00788#011validation-error:0.03603
# [298]#011train-error:0.00785#011validation-error:0.03611
# [299]#011train-error:0.00781#011validation-error:0.03611
# [300]#011train-error:0.00774#011validation-error:0.03603
# [301]#011train-error:0.00772#011validation-error:0.03603
# [302]#011train-error:0.00761#011validation-error:0.03649
# [303]#011train-error:0.00771#011validation-error:0.03649
# [304]#011train-error:0.00760#011validation-error:0.03634
# [305]#011train-error:0.00762#011validation-error:0.03649
# [306]#011train-error:0.00760#011validation-error:0.03642
# [307]#011train-error:0.00742#011validation-error:0.03619
# [308]#011train-error:0.00739#011validation-error:0.03596
# [309]#011train-error:0.00738#011validation-error:0.03603
# [310]#011train-error:0.00734#011validation-error:0.03603
# [311]#011train-error:0.00731#011validation-error:0.03634
# [312]#011train-error:0.00724#011validation-error:0.03634
# [313]#011train-error:0.00723#011validation-error:0.03626
# [314]#011train-error:0.00724#011validation-error:0.03626
# [315]#011train-error:0.00717#011validation-error:0.03626
# [316]#011train-error:0.00703#011validation-error:0.03603
# [317]#011train-error:0.00701#011validation-error:0.03596
# [318]#011train-error:0.00701#011validation-error:0.03611
# [319]#011train-error:0.00702#011validation-error:0.03619
# [320]#011train-error:0.00691#011validation-error:0.03619
# [321]#011train-error:0.00684#011validation-error:0.03619
# [322]#011train-error:0.00677#011validation-error:0.03611
# [323]#011train-error:0.00674#011validation-error:0.03603
# [324]#011train-error:0.00668#011validation-error:0.03596
# [325]#011train-error:0.00667#011validation-error:0.03619
# [326]#011train-error:0.00663#011validation-error:0.03642
# [327]#011train-error:0.00655#011validation-error:0.03642
# [328]#011train-error:0.00646#011validation-error:0.03642
# [329]#011train-error:0.00632#011validation-error:0.03626
# [330]#011train-error:0.00629#011validation-error:0.03611
# [331]#011train-error:0.00629#011validation-error:0.03611
# [332]#011train-error:0.00629#011validation-error:0.03611
# [333]#011train-error:0.00626#011validation-error:0.03603
# [334]#011train-error:0.00626#011validation-error:0.03596
# [335]#011train-error:0.00616#011validation-error:0.03611
# [336]#011train-error:0.00614#011validation-error:0.03619
# [337]#011train-error:0.00609#011validation-error:0.03619
# [338]#011train-error:0.00606#011validation-error:0.03611
# [339]#011train-error:0.00593#011validation-error:0.03626
# [340]#011train-error:0.00595#011validation-error:0.03626
# [341]#011train-error:0.00596#011validation-error:0.03626
# [342]#011train-error:0.00597#011validation-error:0.03619
# [343]#011train-error:0.00590#011validation-error:0.03626
# [344]#011train-error:0.00590#011validation-error:0.03603
# [345]#011train-error:0.00582#011validation-error:0.03588
# [346]#011train-error:0.00579#011validation-error:0.03603
# [347]#011train-error:0.00563#011validation-error:0.03588
# [348]#011train-error:0.00564#011validation-error:0.03596
# [349]#011train-error:0.00559#011validation-error:0.03588
# [350]#011train-error:0.00555#011validation-error:0.03634
# [351]#011train-error:0.00551#011validation-error:0.03657
# [352]#011train-error:0.00551#011validation-error:0.03649
# [353]#011train-error:0.00545#011validation-error:0.03619
# [354]#011train-error:0.00547#011validation-error:0.03619
# [355]#011train-error:0.00544#011validation-error:0.03611
# [356]#011train-error:0.00547#011validation-error:0.03596
# [357]#011train-error:0.00547#011validation-error:0.03596
# [358]#011train-error:0.00545#011validation-error:0.03596
# [359]#011train-error:0.00544#011validation-error:0.03603
# [360]#011train-error:0.00543#011validation-error:0.03626
# [361]#011train-error:0.00538#011validation-error:0.03626
# [362]#011train-error:0.00538#011validation-error:0.03619
# [363]#011train-error:0.00528#011validation-error:0.03619
# [364]#011train-error:0.00528#011validation-error:0.03611
# [365]#011train-error:0.00521#011validation-error:0.03619
# [366]#011train-error:0.00515#011validation-error:0.03603
# [367]#011train-error:0.00511#011validation-error:0.03596
# [368]#011train-error:0.00495#011validation-error:0.03572
# [369]#011train-error:0.00483#011validation-error:0.03565
# [370]#011train-error:0.00481#011validation-error:0.03565
# [371]#011train-error:0.00479#011validation-error:0.03565
# [372]#011train-error:0.00477#011validation-error:0.03580
# [373]#011train-error:0.00477#011validation-error:0.03572
# [374]#011train-error:0.00475#011validation-error:0.03588
# [375]#011train-error:0.00473#011validation-error:0.03580
# [376]#011train-error:0.00475#011validation-error:0.03596
# [377]#011train-error:0.00466#011validation-error:0.03596
# [378]#011train-error:0.00466#011validation-error:0.03611
# [379]#011train-error:0.00463#011validation-error:0.03596
# [380]#011train-error:0.00459#011validation-error:0.03596
# [381]#011train-error:0.00458#011validation-error:0.03588
# [382]#011train-error:0.00456#011validation-error:0.03588
# [383]#011train-error:0.00459#011validation-error:0.03588
# [384]#011train-error:0.00449#011validation-error:0.03588
# [385]#011train-error:0.00446#011validation-error:0.03588
# [386]#011train-error:0.00442#011validation-error:0.03572
# [387]#011train-error:0.00445#011validation-error:0.03596
# [388]#011train-error:0.00440#011validation-error:0.03611
# [389]#011train-error:0.00438#011validation-error:0.03611
# [390]#011train-error:0.00425#011validation-error:0.03649
# [391]#011train-error:0.00425#011validation-error:0.03634
# [392]#011train-error:0.00424#011validation-error:0.03634
# [393]#011train-error:0.00414#011validation-error:0.03657
# [394]#011train-error:0.00412#011validation-error:0.03657
# [395]#011train-error:0.00409#011validation-error:0.03649
# [396]#011train-error:0.00409#011validation-error:0.03657
# [397]#011train-error:0.00406#011validation-error:0.03657
# [398]#011train-error:0.00396#011validation-error:0.03649
# [399]#011train-error:0.00391#011validation-error:0.03634
# [400]#011train-error:0.00389#011validation-error:0.03649
# [401]#011train-error:0.00388#011validation-error:0.03634
# [402]#011train-error:0.00385#011validation-error:0.03649
# [403]#011train-error:0.00384#011validation-error:0.03642
# [404]#011train-error:0.00382#011validation-error:0.03619
# [405]#011train-error:0.00378#011validation-error:0.03611
# [406]#011train-error:0.00376#011validation-error:0.03596
# [407]#011train-error:0.00374#011validation-error:0.03596
# [408]#011train-error:0.00365#011validation-error:0.03580
# [409]#011train-error:0.00363#011validation-error:0.03596
# [410]#011train-error:0.00360#011validation-error:0.03611
# [411]#011train-error:0.00353#011validation-error:0.03611
# [412]#011train-error:0.00356#011validation-error:0.03603
# [413]#011train-error:0.00353#011validation-error:0.03603
# [414]#011train-error:0.00347#011validation-error:0.03603
# [415]#011train-error:0.00346#011validation-error:0.03611
# [416]#011train-error:0.00345#011validation-error:0.03611
# [417]#011train-error:0.00338#011validation-error:0.03588
# [418]#011train-error:0.00335#011validation-error:0.03596
# [419]#011train-error:0.00331#011validation-error:0.03580
# [420]#011train-error:0.00328#011validation-error:0.03588
# [421]#011train-error:0.00323#011validation-error:0.03611
# [422]#011train-error:0.00322#011validation-error:0.03626
# [423]#011train-error:0.00317#011validation-error:0.03603
# [424]#011train-error:0.00315#011validation-error:0.03603
# [425]#011train-error:0.00314#011validation-error:0.03619
# [426]#011train-error:0.00307#011validation-error:0.03603
# [427]#011train-error:0.00303#011validation-error:0.03580
# [428]#011train-error:0.00297#011validation-error:0.03596
# [429]#011train-error:0.00296#011validation-error:0.03603
# [430]#011train-error:0.00294#011validation-error:0.03596
# [431]#011train-error:0.00294#011validation-error:0.03603
# [432]#011train-error:0.00294#011validation-error:0.03565
# [433]#011train-error:0.00293#011validation-error:0.03588
# [434]#011train-error:0.00292#011validation-error:0.03603
# [435]#011train-error:0.00285#011validation-error:0.03619
# [436]#011train-error:0.00281#011validation-error:0.03626
# [437]#011train-error:0.00273#011validation-error:0.03649
# [438]#011train-error:0.00269#011validation-error:0.03642
# [439]#011train-error:0.00270#011validation-error:0.03634
# [440]#011train-error:0.00268#011validation-error:0.03619
# [441]#011train-error:0.00260#011validation-error:0.03619
# [442]#011train-error:0.00256#011validation-error:0.03603
# [443]#011train-error:0.00249#011validation-error:0.03634
# [444]#011train-error:0.00245#011validation-error:0.03611
# [445]#011train-error:0.00240#011validation-error:0.03619
# [446]#011train-error:0.00232#011validation-error:0.03626
# [447]#011train-error:0.00233#011validation-error:0.03626
# [448]#011train-error:0.00227#011validation-error:0.03634
# [449]#011train-error:0.00218#011validation-error:0.03626
# [450]#011train-error:0.00217#011validation-error:0.03626
# [451]#011train-error:0.00217#011validation-error:0.03634
# [452]#011train-error:0.00212#011validation-error:0.03626
# [453]#011train-error:0.00213#011validation-error:0.03649
# [454]#011train-error:0.00208#011validation-error:0.03665
# [455]#011train-error:0.00208#011validation-error:0.03642
# [456]#011train-error:0.00207#011validation-error:0.03649
# [457]#011train-error:0.00208#011validation-error:0.03642
# [458]#011train-error:0.00210#011validation-error:0.03634
# [459]#011train-error:0.00208#011validation-error:0.03649
# [460]#011train-error:0.00208#011validation-error:0.03657
# [461]#011train-error:0.00208#011validation-error:0.03642
# [462]#011train-error:0.00211#011validation-error:0.03642
# [463]#011train-error:0.00209#011validation-error:0.03657
# [464]#011train-error:0.00209#011validation-error:0.03657
# [465]#011train-error:0.00209#011validation-error:0.03657
# [466]#011train-error:0.00206#011validation-error:0.03649
# [467]#011train-error:0.00206#011validation-error:0.03665
# [468]#011train-error:0.00204#011validation-error:0.03649
# [469]#011train-error:0.00203#011validation-error:0.03665
# [470]#011train-error:0.00201#011validation-error:0.03673
# [471]#011train-error:0.00201#011validation-error:0.03673
# [472]#011train-error:0.00195#011validation-error:0.03673
# [473]#011train-error:0.00195#011validation-error:0.03673
# [474]#011train-error:0.00193#011validation-error:0.03665
# [475]#011train-error:0.00193#011validation-error:0.03665
# [476]#011train-error:0.00193#011validation-error:0.03649
# [477]#011train-error:0.00185#011validation-error:0.03665
# [478]#011train-error:0.00183#011validation-error:0.03673
# [479]#011train-error:0.00181#011validation-error:0.03665
# [480]#011train-error:0.00181#011validation-error:0.03673
# [481]#011train-error:0.00176#011validation-error:0.03673
# [482]#011train-error:0.00175#011validation-error:0.03673
# [483]#011train-error:0.00174#011validation-error:0.03680
# [484]#011train-error:0.00174#011validation-error:0.03673
# [485]#011train-error:0.00171#011validation-error:0.03673
# [486]#011train-error:0.00170#011validation-error:0.03673
# [487]#011train-error:0.00168#011validation-error:0.03688
# [488]#011train-error:0.00168#011validation-error:0.03680
# [489]#011train-error:0.00166#011validation-error:0.03657
# [490]#011train-error:0.00166#011validation-error:0.03665
# [491]#011train-error:0.00166#011validation-error:0.03673
# [492]#011train-error:0.00162#011validation-error:0.03642
# [493]#011train-error:0.00160#011validation-error:0.03619
# [494]#011train-error:0.00164#011validation-error:0.03603
# [495]#011train-error:0.00163#011validation-error:0.03642
# [496]#011train-error:0.00154#011validation-error:0.03649
# [497]#011train-error:0.00153#011validation-error:0.03649
# [498]#011train-error:0.00147#011validation-error:0.03649
# [499]#011train-error:0.00146#011validation-error:0.03657
# [500]#011train-error:0.00145#011validation-error:0.03642
# [501]#011train-error:0.00147#011validation-error:0.03657
# [502]#011train-error:0.00143#011validation-error:0.03649
# [503]#011train-error:0.00137#011validation-error:0.03634
# [504]#011train-error:0.00133#011validation-error:0.03649
# [505]#011train-error:0.00134#011validation-error:0.03634
# [506]#011train-error:0.00138#011validation-error:0.03619
# [507]#011train-error:0.00131#011validation-error:0.03649
# [508]#011train-error:0.00132#011validation-error:0.03657
# [509]#011train-error:0.00131#011validation-error:0.03673
# [510]#011train-error:0.00131#011validation-error:0.03673
# [511]#011train-error:0.00127#011validation-error:0.03703
# [512]#011train-error:0.00125#011validation-error:0.03719
# [513]#011train-error:0.00125#011validation-error:0.03703
# [514]#011train-error:0.00127#011validation-error:0.03688
# [515]#011train-error:0.00127#011validation-error:0.03688
# [516]#011train-error:0.00127#011validation-error:0.03680
# [517]#011train-error:0.00129#011validation-error:0.03680
# [518]#011train-error:0.00123#011validation-error:0.03657
# [519]#011train-error:0.00123#011validation-error:0.03665
# [520]#011train-error:0.00122#011validation-error:0.03657
# [521]#011train-error:0.00121#011validation-error:0.03649
# [522]#011train-error:0.00124#011validation-error:0.03657
# [523]#011train-error:0.00123#011validation-error:0.03642
# [524]#011train-error:0.00122#011validation-error:0.03649
# [525]#011train-error:0.00122#011validation-error:0.03642
# [526]#011train-error:0.00122#011validation-error:0.03642
# [527]#011train-error:0.00122#011validation-error:0.03642
# [528]#011train-error:0.00124#011validation-error:0.03634
# [529]#011train-error:0.00124#011validation-error:0.03665
# [530]#011train-error:0.00122#011validation-error:0.03657
# [531]#011train-error:0.00121#011validation-error:0.03649
# [532]#011train-error:0.00120#011validation-error:0.03642
# [533]#011train-error:0.00119#011validation-error:0.03649
# [534]#011train-error:0.00117#011validation-error:0.03649
# [535]#011train-error:0.00114#011validation-error:0.03657
# [536]#011train-error:0.00114#011validation-error:0.03657
# [537]#011train-error:0.00112#011validation-error:0.03649
# [538]#011train-error:0.00109#011validation-error:0.03642
# [539]#011train-error:0.00109#011validation-error:0.03634
# [540]#011train-error:0.00106#011validation-error:0.03626
# [541]#011train-error:0.00106#011validation-error:0.03619
# [542]#011train-error:0.00108#011validation-error:0.03634
# [543]#011train-error:0.00106#011validation-error:0.03619
# [544]#011train-error:0.00106#011validation-error:0.03634
# [545]#011train-error:0.00102#011validation-error:0.03626
# [546]#011train-error:0.00097#011validation-error:0.03634
# [547]#011train-error:0.00098#011validation-error:0.03626
# [548]#011train-error:0.00095#011validation-error:0.03642
# [549]#011train-error:0.00095#011validation-error:0.03649
# [550]#011train-error:0.00093#011validation-error:0.03619
# [551]#011train-error:0.00092#011validation-error:0.03619
# [552]#011train-error:0.00091#011validation-error:0.03626
# [553]#011train-error:0.00090#011validation-error:0.03634
# [554]#011train-error:0.00090#011validation-error:0.03626
# [555]#011train-error:0.00090#011validation-error:0.03611
# [556]#011train-error:0.00091#011validation-error:0.03619
# [557]#011train-error:0.00090#011validation-error:0.03596
# [558]#011train-error:0.00087#011validation-error:0.03603
# [559]#011train-error:0.00087#011validation-error:0.03603
# [560]#011train-error:0.00088#011validation-error:0.03634
# [561]#011train-error:0.00088#011validation-error:0.03626
# [562]#011train-error:0.00086#011validation-error:0.03603
# [563]#011train-error:0.00085#011validation-error:0.03611
# [564]#011train-error:0.00084#011validation-error:0.03611
# [565]#011train-error:0.00084#011validation-error:0.03626
# [566]#011train-error:0.00084#011validation-error:0.03619
# [567]#011train-error:0.00085#011validation-error:0.03642
# [568]#011train-error:0.00082#011validation-error:0.03634
# [569]#011train-error:0.00082#011validation-error:0.03619
# [570]#011train-error:0.00080#011validation-error:0.03596
# [571]#011train-error:0.00080#011validation-error:0.03603
# [572]#011train-error:0.00082#011validation-error:0.03596
# [573]#011train-error:0.00080#011validation-error:0.03619
# [574]#011train-error:0.00076#011validation-error:0.03596
# [575]#011train-error:0.00077#011validation-error:0.03596
# [576]#011train-error:0.00077#011validation-error:0.03596
# [577]#011train-error:0.00077#011validation-error:0.03603
# [578]#011train-error:0.00078#011validation-error:0.03603
# [579]#011train-error:0.00076#011validation-error:0.03626
# [580]#011train-error:0.00075#011validation-error:0.03626
# [581]#011train-error:0.00074#011validation-error:0.03611
# [582]#011train-error:0.00073#011validation-error:0.03611
# [583]#011train-error:0.00072#011validation-error:0.03619
# [584]#011train-error:0.00072#011validation-error:0.03634
# [585]#011train-error:0.00072#011validation-error:0.03634
# [586]#011train-error:0.00073#011validation-error:0.03626
# [587]#011train-error:0.00073#011validation-error:0.03619
# [588]#011train-error:0.00071#011validation-error:0.03603
# [589]#011train-error:0.00064#011validation-error:0.03619
# [590]#011train-error:0.00064#011validation-error:0.03611
# [591]#011train-error:0.00064#011validation-error:0.03619
# [592]#011train-error:0.00064#011validation-error:0.03611
# [593]#011train-error:0.00063#011validation-error:0.03603
# [594]#011train-error:0.00063#011validation-error:0.03596
# [595]#011train-error:0.00062#011validation-error:0.03619
# [596]#011train-error:0.00063#011validation-error:0.03619
# [597]#011train-error:0.00064#011validation-error:0.03619
# [598]#011train-error:0.00064#011validation-error:0.03603
# [599]#011train-error:0.00062#011validation-error:0.03634
# [600]#011train-error:0.00062#011validation-error:0.03642
# [601]#011train-error:0.00059#011validation-error:0.03642
# [602]#011train-error:0.00060#011validation-error:0.03665
# [603]#011train-error:0.00058#011validation-error:0.03642
# [604]#011train-error:0.00061#011validation-error:0.03665
# [605]#011train-error:0.00061#011validation-error:0.03665
# [606]#011train-error:0.00062#011validation-error:0.03688
# [607]#011train-error:0.00060#011validation-error:0.03688
# [608]#011train-error:0.00058#011validation-error:0.03665
# [609]#011train-error:0.00058#011validation-error:0.03657
# [610]#011train-error:0.00056#011validation-error:0.03665
# [611]#011train-error:0.00057#011validation-error:0.03649
# [612]#011train-error:0.00057#011validation-error:0.03657
# [613]#011train-error:0.00057#011validation-error:0.03673
# [614]#011train-error:0.00057#011validation-error:0.03649
# [615]#011train-error:0.00057#011validation-error:0.03642
# [616]#011train-error:0.00057#011validation-error:0.03649
# [617]#011train-error:0.00057#011validation-error:0.03642
# [618]#011train-error:0.00057#011validation-error:0.03626
# [619]#011train-error:0.00055#011validation-error:0.03634
# [620]#011train-error:0.00055#011validation-error:0.03634
# [621]#011train-error:0.00055#011validation-error:0.03626
# [622]#011train-error:0.00054#011validation-error:0.03634
# [623]#011train-error:0.00054#011validation-error:0.03642
# [624]#011train-error:0.00054#011validation-error:0.03642
# [625]#011train-error:0.00054#011validation-error:0.03642
# [626]#011train-error:0.00054#011validation-error:0.03634
# [627]#011train-error:0.00053#011validation-error:0.03626
# [628]#011train-error:0.00053#011validation-error:0.03634
# [629]#011train-error:0.00050#011validation-error:0.03611
# [630]#011train-error:0.00049#011validation-error:0.03603
# [631]#011train-error:0.00047#011validation-error:0.03588
# [632]#011train-error:0.00047#011validation-error:0.03580
# [633]#011train-error:0.00047#011validation-error:0.03603
# [634]#011train-error:0.00044#011validation-error:0.03596
# [635]#011train-error:0.00044#011validation-error:0.03588
# [636]#011train-error:0.00044#011validation-error:0.03611
# [637]#011train-error:0.00044#011validation-error:0.03596
# [638]#011train-error:0.00044#011validation-error:0.03603
# [639]#011train-error:0.00045#011validation-error:0.03596
# [640]#011train-error:0.00045#011validation-error:0.03596
# [641]#011train-error:0.00045#011validation-error:0.03603
# [642]#011train-error:0.00044#011validation-error:0.03626
# [643]#011train-error:0.00044#011validation-error:0.03626
# [644]#011train-error:0.00043#011validation-error:0.03626
# [645]#011train-error:0.00043#011validation-error:0.03634
# [646]#011train-error:0.00042#011validation-error:0.03619
# [647]#011train-error:0.00042#011validation-error:0.03649
# [648]#011train-error:0.00040#011validation-error:0.03649
# [649]#011train-error:0.00040#011validation-error:0.03649
# [650]#011train-error:0.00040#011validation-error:0.03649
# [651]#011train-error:0.00037#011validation-error:0.03642
# [652]#011train-error:0.00037#011validation-error:0.03649
# [653]#011train-error:0.00038#011validation-error:0.03649
# [654]#011train-error:0.00038#011validation-error:0.03665
# [655]#011train-error:0.00037#011validation-error:0.03665
# [656]#011train-error:0.00033#011validation-error:0.03673
# [657]#011train-error:0.00032#011validation-error:0.03649
# [658]#011train-error:0.00033#011validation-error:0.03642
# [659]#011train-error:0.00033#011validation-error:0.03649
# [660]#011train-error:0.00032#011validation-error:0.03634
# [661]#011train-error:0.00032#011validation-error:0.03665
# [662]#011train-error:0.00029#011validation-error:0.03673
# [663]#011train-error:0.00028#011validation-error:0.03673
# [664]#011train-error:0.00028#011validation-error:0.03665
# [665]#011train-error:0.00028#011validation-error:0.03642
# [666]#011train-error:0.00028#011validation-error:0.03649
# [667]#011train-error:0.00026#011validation-error:0.03634
# [668]#011train-error:0.00027#011validation-error:0.03634
# [669]#011train-error:0.00024#011validation-error:0.03634
# [670]#011train-error:0.00024#011validation-error:0.03626
# [671]#011train-error:0.00021#011validation-error:0.03634
# [672]#011train-error:0.00021#011validation-error:0.03626
# [673]#011train-error:0.00022#011validation-error:0.03619
# [674]#011train-error:0.00024#011validation-error:0.03603
# [675]#011train-error:0.00024#011validation-error:0.03626
# [676]#011train-error:0.00024#011validation-error:0.03642
# [677]#011train-error:0.00024#011validation-error:0.03634
# [678]#011train-error:0.00023#011validation-error:0.03619
# [679]#011train-error:0.00023#011validation-error:0.03619
# [680]#011train-error:0.00023#011validation-error:0.03619
# [681]#011train-error:0.00022#011validation-error:0.03611
# [682]#011train-error:0.00022#011validation-error:0.03611
# [683]#011train-error:0.00022#011validation-error:0.03619
# [684]#011train-error:0.00021#011validation-error:0.03634
# [685]#011train-error:0.00021#011validation-error:0.03642
# [686]#011train-error:0.00020#011validation-error:0.03642
# [687]#011train-error:0.00020#011validation-error:0.03649
# [688]#011train-error:0.00020#011validation-error:0.03649
# [689]#011train-error:0.00020#011validation-error:0.03657
# [690]#011train-error:0.00020#011validation-error:0.03642
# [691]#011train-error:0.00020#011validation-error:0.03634
# [692]#011train-error:0.00020#011validation-error:0.03619
# [693]#011train-error:0.00020#011validation-error:0.03634
# [694]#011train-error:0.00020#011validation-error:0.03634
# [695]#011train-error:0.00020#011validation-error:0.03634
# [696]#011train-error:0.00018#011validation-error:0.03619
# [697]#011train-error:0.00017#011validation-error:0.03642
# [698]#011train-error:0.00017#011validation-error:0.03642
# [699]#011train-error:0.00017#011validation-error:0.03634
# [700]#011train-error:0.00017#011validation-error:0.03649
# [701]#011train-error:0.00018#011validation-error:0.03649
# [702]#011train-error:0.00018#011validation-error:0.03649
# [703]#011train-error:0.00017#011validation-error:0.03634
# [704]#011train-error:0.00016#011validation-error:0.03642
# [705]#011train-error:0.00015#011validation-error:0.03649
# [706]#011train-error:0.00015#011validation-error:0.03657
# [707]#011train-error:0.00015#011validation-error:0.03634
# [708]#011train-error:0.00015#011validation-error:0.03649
# [709]#011train-error:0.00015#011validation-error:0.03665
# [710]#011train-error:0.00015#011validation-error:0.03665
# [711]#011train-error:0.00015#011validation-error:0.03665
# [712]#011train-error:0.00015#011validation-error:0.03657
# [713]#011train-error:0.00015#011validation-error:0.03657
# [714]#011train-error:0.00015#011validation-error:0.03657
# [715]#011train-error:0.00015#011validation-error:0.03657
# [716]#011train-error:0.00015#011validation-error:0.03657
# [717]#011train-error:0.00015#011validation-error:0.03642
# [718]#011train-error:0.00014#011validation-error:0.03649
# [719]#011train-error:0.00014#011validation-error:0.03665
# [720]#011train-error:0.00014#011validation-error:0.03665
# [721]#011train-error:0.00014#011validation-error:0.03665
# [722]#011train-error:0.00013#011validation-error:0.03657
# [723]#011train-error:0.00013#011validation-error:0.03649
# [724]#011train-error:0.00013#011validation-error:0.03680
# [725]#011train-error:0.00013#011validation-error:0.03680
# [726]#011train-error:0.00013#011validation-error:0.03657
# [727]#011train-error:0.00013#011validation-error:0.03657
# [728]#011train-error:0.00013#011validation-error:0.03657
# [729]#011train-error:0.00013#011validation-error:0.03649
# [730]#011train-error:0.00012#011validation-error:0.03649
# [731]#011train-error:0.00012#011validation-error:0.03657
# [732]#011train-error:0.00012#011validation-error:0.03665
# [733]#011train-error:0.00013#011validation-error:0.03649
# [734]#011train-error:0.00013#011validation-error:0.03673
# [735]#011train-error:0.00013#011validation-error:0.03665
# [736]#011train-error:0.00013#011validation-error:0.03634
# [737]#011train-error:0.00013#011validation-error:0.03619
# [738]#011train-error:0.00013#011validation-error:0.03603
# [739]#011train-error:0.00013#011validation-error:0.03619
# [740]#011train-error:0.00013#011validation-error:0.03626
# [741]#011train-error:0.00013#011validation-error:0.03634
# [742]#011train-error:0.00013#011validation-error:0.03626
# [743]#011train-error:0.00013#011validation-error:0.03642
# [744]#011train-error:0.00012#011validation-error:0.03642
# [745]#011train-error:0.00012#011validation-error:0.03657
# [746]#011train-error:0.00012#011validation-error:0.03626
# [747]#011train-error:0.00012#011validation-error:0.03626
# [748]#011train-error:0.00012#011validation-error:0.03642
# [749]#011train-error:0.00012#011validation-error:0.03626
# [750]#011train-error:0.00012#011validation-error:0.03634
# [751]#011train-error:0.00012#011validation-error:0.03626
# [752]#011train-error:0.00012#011validation-error:0.03642
# [753]#011train-error:0.00012#011validation-error:0.03649
# [754]#011train-error:0.00012#011validation-error:0.03642
# [755]#011train-error:0.00012#011validation-error:0.03642
# [756]#011train-error:0.00012#011validation-error:0.03673
# [757]#011train-error:0.00012#011validation-error:0.03680
# [758]#011train-error:0.00012#011validation-error:0.03680
# [759]#011train-error:0.00012#011validation-error:0.03673
# [760]#011train-error:0.00012#011validation-error:0.03665
# [761]#011train-error:0.00012#011validation-error:0.03680
# [762]#011train-error:0.00011#011validation-error:0.03673
# [763]#011train-error:0.00011#011validation-error:0.03688
# [764]#011train-error:0.00011#011validation-error:0.03696
# [765]#011train-error:0.00011#011validation-error:0.03680
# [766]#011train-error:0.00011#011validation-error:0.03680
# [767]#011train-error:0.00011#011validation-error:0.03657
# [768]#011train-error:0.00011#011validation-error:0.03634
# [769]#011train-error:0.00011#011validation-error:0.03626
# [770]#011train-error:0.00011#011validation-error:0.03626
# [771]#011train-error:0.00011#011validation-error:0.03649
# [772]#011train-error:0.00011#011validation-error:0.03642
# [773]#011train-error:0.00011#011validation-error:0.03649
# [774]#011train-error:0.00011#011validation-error:0.03634
# [775]#011train-error:0.00011#011validation-error:0.03634
# [776]#011train-error:0.00008#011validation-error:0.03611
# [777]#011train-error:0.00008#011validation-error:0.03634
# [778]#011train-error:0.00008#011validation-error:0.03634
# [779]#011train-error:0.00008#011validation-error:0.03634
# [780]#011train-error:0.00008#011validation-error:0.03642
# [781]#011train-error:0.00008#011validation-error:0.03634
# [782]#011train-error:0.00009#011validation-error:0.03619
# [783]#011train-error:0.00009#011validation-error:0.03634
# [784]#011train-error:0.00008#011validation-error:0.03642
# [785]#011train-error:0.00008#011validation-error:0.03649
# [786]#011train-error:0.00008#011validation-error:0.03657
# [787]#011train-error:0.00008#011validation-error:0.03634
# [788]#011train-error:0.00008#011validation-error:0.03642
# [789]#011train-error:0.00008#011validation-error:0.03626
# [790]#011train-error:0.00007#011validation-error:0.03634
# [791]#011train-error:0.00007#011validation-error:0.03634
# [792]#011train-error:0.00007#011validation-error:0.03642
# [793]#011train-error:0.00007#011validation-error:0.03649
# [794]#011train-error:0.00007#011validation-error:0.03642
# [795]#011train-error:0.00007#011validation-error:0.03634
# [796]#011train-error:0.00007#011validation-error:0.03634
# [797]#011train-error:0.00007#011validation-error:0.03634
# [798]#011train-error:0.00007#011validation-error:0.03626
# [799]#011train-error:0.00007#011validation-error:0.03626
# [800]#011train-error:0.00007#011validation-error:0.03634
# [801]#011train-error:0.00007#011validation-error:0.03626
# [802]#011train-error:0.00007#011validation-error:0.03626
# [803]#011train-error:0.00006#011validation-error:0.03611
# [804]#011train-error:0.00005#011validation-error:0.03626
# [805]#011train-error:0.00005#011validation-error:0.03619
# [806]#011train-error:0.00005#011validation-error:0.03611
# [807]#011train-error:0.00005#011validation-error:0.03626
# [808]#011train-error:0.00005#011validation-error:0.03619
# [809]#011train-error:0.00004#011validation-error:0.03603
# [810]#011train-error:0.00003#011validation-error:0.03619
# [811]#011train-error:0.00004#011validation-error:0.03603
# [812]#011train-error:0.00003#011validation-error:0.03603
# [813]#011train-error:0.00003#011validation-error:0.03596
# [814]#011train-error:0.00004#011validation-error:0.03626
# [815]#011train-error:0.00003#011validation-error:0.03619
# [816]#011train-error:0.00003#011validation-error:0.03634
# [817]#011train-error:0.00003#011validation-error:0.03611
# [818]#011train-error:0.00003#011validation-error:0.03611
# [819]#011train-error:0.00003#011validation-error:0.03611
# [820]#011train-error:0.00004#011validation-error:0.03611
# [821]#011train-error:0.00004#011validation-error:0.03619
# [822]#011train-error:0.00004#011validation-error:0.03619
# [823]#011train-error:0.00004#011validation-error:0.03611
# [824]#011train-error:0.00004#011validation-error:0.03611
# [825]#011train-error:0.00004#011validation-error:0.03603
# [826]#011train-error:0.00004#011validation-error:0.03603
# [827]#011train-error:0.00004#011validation-error:0.03619
# [828]#011train-error:0.00003#011validation-error:0.03619
# [829]#011train-error:0.00003#011validation-error:0.03634
# [830]#011train-error:0.00003#011validation-error:0.03626
# [831]#011train-error:0.00003#011validation-error:0.03642
# [832]#011train-error:0.00003#011validation-error:0.03642
# [833]#011train-error:0.00003#011validation-error:0.03649
# [834]#011train-error:0.00003#011validation-error:0.03642
# [835]#011train-error:0.00003#011validation-error:0.03642
# [836]#011train-error:0.00003#011validation-error:0.03626
# [837]#011train-error:0.00003#011validation-error:0.03626
# [838]#011train-error:0.00003#011validation-error:0.03626
# [839]#011train-error:0.00003#011validation-error:0.03642
# [840]#011train-error:0.00003#011validation-error:0.03626
# [841]#011train-error:0.00003#011validation-error:0.03626
# [842]#011train-error:0.00003#011validation-error:0.03626
# [843]#011train-error:0.00003#011validation-error:0.03619
# [844]#011train-error:0.00003#011validation-error:0.03611
# [845]#011train-error:0.00004#011validation-error:0.03619
# [846]#011train-error:0.00004#011validation-error:0.03626
# [847]#011train-error:0.00004#011validation-error:0.03642
# [848]#011train-error:0.00004#011validation-error:0.03642
# [849]#011train-error:0.00004#011validation-error:0.03619
# [850]#011train-error:0.00004#011validation-error:0.03626
# [851]#011train-error:0.00003#011validation-error:0.03634
# [852]#011train-error:0.00003#011validation-error:0.03626
# [853]#011train-error:0.00002#011validation-error:0.03626
# [854]#011train-error:0.00002#011validation-error:0.03619
# [855]#011train-error:0.00002#011validation-error:0.03626
# [856]#011train-error:0.00002#011validation-error:0.03626
# [857]#011train-error:0.00002#011validation-error:0.03626
# [858]#011train-error:0.00002#011validation-error:0.03619
# [859]#011train-error:0.00002#011validation-error:0.03634
# [860]#011train-error:0.00002#011validation-error:0.03611
# [861]#011train-error:0.00002#011validation-error:0.03603
# [862]#011train-error:0.00002#011validation-error:0.03596
# [863]#011train-error:0.00001#011validation-error:0.03619
# [864]#011train-error:0.00002#011validation-error:0.03619
# [865]#011train-error:0.00001#011validation-error:0.03603
# [866]#011train-error:0.00002#011validation-error:0.03619
# [867]#011train-error:0.00002#011validation-error:0.03626
# [868]#011train-error:0.00002#011validation-error:0.03619
# [869]#011train-error:0.00002#011validation-error:0.03619
# [870]#011train-error:0.00002#011validation-error:0.03619
# [871]#011train-error:0.00002#011validation-error:0.03611
# [872]#011train-error:0.00002#011validation-error:0.03611
# [873]#011train-error:0.00002#011validation-error:0.03611
# [874]#011train-error:0.00002#011validation-error:0.03619
# [875]#011train-error:0.00002#011validation-error:0.03619
# [876]#011train-error:0.00002#011validation-error:0.03626
# [877]#011train-error:0.00002#011validation-error:0.03619
# [878]#011train-error:0.00002#011validation-error:0.03626
# [879]#011train-error:0.00001#011validation-error:0.03626
# [880]#011train-error:0.00001#011validation-error:0.03634
# [881]#011train-error:0.00001#011validation-error:0.03634
# [882]#011train-error:0.00001#011validation-error:0.03626
# [883]#011train-error:0.00001#011validation-error:0.03626
# [884]#011train-error:0.00001#011validation-error:0.03626
# [885]#011train-error:0.00001#011validation-error:0.03634
# [886]#011train-error:0.00001#011validation-error:0.03626
# [887]#011train-error:0.00001#011validation-error:0.03626
# [888]#011train-error:0.00001#011validation-error:0.03626
# [889]#011train-error:0.00001#011validation-error:0.03626
# [890]#011train-error:0.00001#011validation-error:0.03619
# [891]#011train-error:0.00001#011validation-error:0.03619
# [892]#011train-error:0.00001#011validation-error:0.03619
# [893]#011train-error:0.00001#011validation-error:0.03619
# [894]#011train-error:0.00001#011validation-error:0.03626
# [895]#011train-error:0.00001#011validation-error:0.03619
# [896]#011train-error:0.00001#011validation-error:0.03619
# [897]#011train-error:0.00001#011validation-error:0.03611
# [898]#011train-error:0.00001#011validation-error:0.03611
# [899]#011train-error:0.00001#011validation-error:0.03611
# [900]#011train-error:0.00001#011validation-error:0.03603
# [901]#011train-error:0.00001#011validation-error:0.03603
# [902]#011train-error:0.00001#011validation-error:0.03619
# [903]#011train-error:0.00001#011validation-error:0.03642
# [904]#011train-error:0.00001#011validation-error:0.03619
# [905]#011train-error:0.00001#011validation-error:0.03619
# [906]#011train-error:0.00001#011validation-error:0.03626
# [907]#011train-error:0.00001#011validation-error:0.03619
# [908]#011train-error:0.00001#011validation-error:0.03596
# [909]#011train-error:0.00001#011validation-error:0.03565
# [910]#011train-error:0.00001#011validation-error:0.03557
# [911]#011train-error:0.00001#011validation-error:0.03572
# [912]#011train-error:0.00001#011validation-error:0.03580
# [913]#011train-error:0.00001#011validation-error:0.03611
# [914]#011train-error:0.00001#011validation-error:0.03596
# [915]#011train-error:0.00001#011validation-error:0.03603
# [916]#011train-error:0.00001#011validation-error:0.03603
# [917]#011train-error:0.00001#011validation-error:0.03596
# [918]#011train-error:0.00001#011validation-error:0.03596
# [919]#011train-error:0.00000#011validation-error:0.03588
# [920]#011train-error:0.00000#011validation-error:0.03588
# [921]#011train-error:0.00000#011validation-error:0.03588
# [922]#011train-error:0.00000#011validation-error:0.03580
# [923]#011train-error:0.00000#011validation-error:0.03588
# [924]#011train-error:0.00000#011validation-error:0.03588
# [925]#011train-error:0.00000#011validation-error:0.03603
# [926]#011train-error:0.00000#011validation-error:0.03603
# [927]#011train-error:0.00000#011validation-error:0.03603
# [928]#011train-error:0.00000#011validation-error:0.03596
# [929]#011train-error:0.00000#011validation-error:0.03588
# [930]#011train-error:0.00000#011validation-error:0.03572
# [931]#011train-error:0.00000#011validation-error:0.03572
# [932]#011train-error:0.00000#011validation-error:0.03565
# [933]#011train-error:0.00000#011validation-error:0.03557
# [934]#011train-error:0.00000#011validation-error:0.03565
# [935]#011train-error:0.00000#011validation-error:0.03557
# [936]#011train-error:0.00000#011validation-error:0.03557
# [937]#011train-error:0.00000#011validation-error:0.03557
# [938]#011train-error:0.00000#011validation-error:0.03549
# [939]#011train-error:0.00000#011validation-error:0.03565
# [940]#011train-error:0.00000#011validation-error:0.03557
# [941]#011train-error:0.00000#011validation-error:0.03549
# [942]#011train-error:0.00000#011validation-error:0.03549
# [943]#011train-error:0.00000#011validation-error:0.03557
# [944]#011train-error:0.00000#011validation-error:0.03572
# [945]#011train-error:0.00000#011validation-error:0.03572
# [946]#011train-error:0.00000#011validation-error:0.03588
# [947]#011train-error:0.00000#011validation-error:0.03611
# [948]#011train-error:0.00000#011validation-error:0.03588
# [949]#011train-error:0.00000#011validation-error:0.03596
# [950]#011train-error:0.00000#011validation-error:0.03603
# [951]#011train-error:0.00000#011validation-error:0.03603
# [952]#011train-error:0.00000#011validation-error:0.03596
# [953]#011train-error:0.00000#011validation-error:0.03619
# [954]#011train-error:0.00000#011validation-error:0.03611
# [955]#011train-error:0.00000#011validation-error:0.03588
# [956]#011train-error:0.00000#011validation-error:0.03580
# [957]#011train-error:0.00000#011validation-error:0.03580
# [958]#011train-error:0.00000#011validation-error:0.03580
# [959]#011train-error:0.00000#011validation-error:0.03596
# [960]#011train-error:0.00000#011validation-error:0.03603
# [961]#011train-error:0.00000#011validation-error:0.03603
# [962]#011train-error:0.00000#011validation-error:0.03596
# [963]#011train-error:0.00000#011validation-error:0.03580
# [964]#011train-error:0.00000#011validation-error:0.03580
# [965]#011train-error:0.00000#011validation-error:0.03588
# [966]#011train-error:0.00000#011validation-error:0.03572
# [967]#011train-error:0.00000#011validation-error:0.03572
# [968]#011train-error:0.00000#011validation-error:0.03572
# [969]#011train-error:0.00000#011validation-error:0.03588
# [970]#011train-error:0.00000#011validation-error:0.03588
# [971]#011train-error:0.00000#011validation-error:0.03588
# [972]#011train-error:0.00000#011validation-error:0.03580
# [973]#011train-error:0.00000#011validation-error:0.03565
# [974]#011train-error:0.00000#011validation-error:0.03565
# [975]#011train-error:0.00000#011validation-error:0.03565
# [976]#011train-error:0.00000#011validation-error:0.03549
# [977]#011train-error:0.00000#011validation-error:0.03542
# [978]#011train-error:0.00000#011validation-error:0.03557
# [979]#011train-error:0.00000#011validation-error:0.03588
# [980]#011train-error:0.00000#011validation-error:0.03580
# [981]#011train-error:0.00000#011validation-error:0.03580
# [982]#011train-error:0.00000#011validation-error:0.03580
# [983]#011train-error:0.00000#011validation-error:0.03588
# [984]#011train-error:0.00000#011validation-error:0.03596
# [985]#011train-error:0.00000#011validation-error:0.03611
# [986]#011train-error:0.00000#011validation-error:0.03603
# [987]#011train-error:0.00000#011validation-error:0.03603
# [988]#011train-error:0.00000#011validation-error:0.03603
# [989]#011train-error:0.00000#011validation-error:0.03596
# [990]#011train-error:0.00000#011validation-error:0.03580
# [991]#011train-error:0.00000#011validation-error:0.03565
# [992]#011train-error:0.00000#011validation-error:0.03565
# [993]#011train-error:0.00000#011validation-error:0.03572
# [994]#011train-error:0.00000#011validation-error:0.03572
# [995]#011train-error:0.00000#011validation-error:0.03580
# [996]#011train-error:0.00000#011validation-error:0.03580
# [997]#011train-error:0.00000#011validation-error:0.03580
# [998]#011train-error:0.00000#011validation-error:0.03572
# [999]#011train-error:0.00000#011validation-error:0.03580
#
# 2024-04-01 20:25:51 Uploading - Uploading generated training model
# 2024-04-01 20:25:51 Completed - Training job completed
# Training seconds: 208
# Billable seconds: 208

# %% [markdown]
# # Get training job name
# Training job name.

# %%
xgboost_model._current_job_name
# Out:
# 'sagemaker-xgboost-2024-04-01-20-21-28-858'

# %% [markdown]
# # Deploy the trained model
# The trained model is deployed to a SageMaker endpoint for making predictions.

# %%
predictor = xgboost_model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge', serializer=sagemaker.serializers.CSVSerializer())
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2024-04-01-20-26-12-964
# INFO:sagemaker:Creating endpoint-config with name sagemaker-xgboost-2024-04-01-20-26-12-964
# INFO:sagemaker:Creating endpoint with name sagemaker-xgboost-2024-04-01-20-26-12-964
# -------!

# %% [markdown]
# # Make predictions and calculate evaluation metrics
# Predictions are made using the deployed model, and evaluation metrics like accuracy, precision, recall, F1 score, and ROC-AUC are calculated and printed.

# %%
predictor.serializer = CSVSerializer()

# %%
predictions = predictor.predict(X_test.to_csv(header=False, index=False)).decode("utf-8")

# %%
prediction_values = np.fromstring(predictions[1:-1], sep=',')

# %%
# Convert predictions to binary (this step might vary based on your specific use case)
predicted_labels = np.where(prediction_values > 0.5, 1, 0)

# Calculate metrics
accuracy = accuracy_score(y_test, predicted_labels)
precision = precision_score(y_test, predicted_labels)
recall = recall_score(y_test, predicted_labels)
f1 = f1_score(y_test, predicted_labels)
roc_auc = roc_auc_score(y_test, prediction_values)  # Use prediction values directly for AUC

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"ROC-AUC: {roc_auc}")
# Out:
# Accuracy: 0.9608869725900832
# Precision: 0.9653860094237042
# Recall: 0.9438341601700921
# F1 Score: 0.9544884429313744
# ROC-AUC: 0.9944481163793969
